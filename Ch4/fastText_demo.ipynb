# %% [markdown]
# Text classification dataset DBPedia. The dataset consists of text descriptions of 14 different classes. The training set contains 560,000 reviews and the test contains 70,000. Idea is to build a model that can predict the class from description.
#
#
# Download dataset from [here](https://drive.google.com/drive/folders/0Bz8a_Dbh9Qhbfll6bVpmNUtUcFdjYmF2SEpmZUZUcVNiMUw1TWN6RDV3a0JHT3kxLVhVR2M).

# %%
import os,sys  
import pandas as pd
import numpy as np
import fasttext

# %%
# Set dataset path

data_path = './dbpedia_csv/'

#Load train set
train_file = data_path + 'dbpedia_train.csv'
df = pd.read_csv(train_file, header=None, names=['class','name','description'])

#Load test set
test_file = data_path + 'dbpedia_test.csv'
df_test = pd.read_csv(test_file, header=None, names=['class','name','description'])

#Mapping from class number to class name
class_dict={
1:'Company',
2:'EducationalInstitution',
3:'Artist',
4:'Athlete',
5:'OfficeHolder',
6:'MeanOfTransportation',
7:'Building',
8:'NaturalPlace',
9:'Village',
10:'Animal',
11:'Plant',
12:'Album',
13:'Film',
14:'WrittenWork'
}
df['class_name'] = df['class'].map(class_dict)
df.head()
df.tail()
# Out:
#         class                      name  \
# 559995     14          Barking in Essex
# 559996     14          Science & Spirit
# 559997     14    The Blithedale Romance
# 559998     14       Razadarit Ayedawbon
# 559999     14  The Vinyl Cafe Notebooks
#
#                                               description   class_name
# 559995   Barking in Essex is a Black comedy play direc...  WrittenWork
# 559996   Science & Spirit is a discontinued American b...  WrittenWork
# 559997   The Blithedale Romance (1852) is Nathaniel Ha...  WrittenWork
# 559998   Razadarit Ayedawbon (Burmese: ရာဇာဓိရာဇ် အရေး...  WrittenWork
# 559999   Vinyl Cafe Notebooks: a collection of essays ...  WrittenWork

# %%
df.head()
# Out:
#    class                               name  \
# 0      1                   E. D. Abbott Ltd
# 1      1                     Schwan-Stabilo
# 2      1                         Q-workshop
# 3      1  Marvell Software Solutions Israel
# 4      1        Bergan Mercy Medical Center
#
#                                          description class_name
# 0   Abbott of Farnham E D Abbott Limited was a Br...    Company
# 1   Schwan-STABILO is a German maker of pens for ...    Company
# 2   Q-workshop is a Polish company located in Poz...    Company
# 3   Marvell Software Solutions Israel known as RA...    Company
# 4   Bergan Mercy Medical Center is a hospital loc...    Company

# %%
df.tail()
# Out:
#         class                      name  \
# 559995     14          Barking in Essex
# 559996     14          Science & Spirit
# 559997     14    The Blithedale Romance
# 559998     14       Razadarit Ayedawbon
# 559999     14  The Vinyl Cafe Notebooks
#
#                                               description   class_name
# 559995   Barking in Essex is a Black comedy play direc...  WrittenWork
# 559996   Science & Spirit is a discontinued American b...  WrittenWork
# 559997   The Blithedale Romance (1852) is Nathaniel Ha...  WrittenWork
# 559998   Razadarit Ayedawbon (Burmese: ရာဇာဓိရာဇ် အရေး...  WrittenWork
# 559999   Vinyl Cafe Notebooks: a collection of essays ...  WrittenWork

# %%
#df.describe().transpose()
desc = df.groupby('class')
desc.describe()
# Out:
#                           class_name  \
# class
# 1     count                    40000
#       unique                       1
#       top                    Company
#       freq                     40000
# 2     count                    40000
#       unique                       1
#       top     EducationalInstitution
#       freq                     40000
# 3     count                    40000
#       unique                       1
#       top                     Artist
#       freq                     40000
# 4     count                    40000
#       unique                       1
#       top                    Athlete
#       freq                     40000
# 5     count                    40000
#       unique                       1
#       top               OfficeHolder
#       freq                     40000
# 6     count                    40000
#       unique                       1
#       top       MeanOfTransportation
#       freq                     40000
# 7     count                    40000
#       unique                       1
#       top                   Building
#       freq                     40000
# 8     count                    40000
#       unique                       1
#       top               NaturalPlace
#       freq                     40000
# 9     count                    40000
#       unique                       1
#       top                    Village
#       freq                     40000
# 10    count                    40000
#       unique                       1
#       top                     Animal
#       freq                     40000
# 11    count                    40000
#       unique                       1
#       top                      Plant
#       freq                     40000
# 12    count                    40000
#       unique                       1
#       top                      Album
#       freq                     40000
# 13    count                    40000
#       unique                       1
#       top                       Film
#       freq                     40000
# 14    count                    40000
#       unique                       1
#       top                WrittenWork
#       freq                     40000
#
#                                                     description  \
# class
# 1     count                                               40000
#       unique                                              39996
#       top      MegaPath Corporation—headquartered in Pleasan...
#       freq                                                    2
# 2     count                                               40000
#       unique                                              39992
#       top      Dr. Meghnad Saha College is a college in Itah...
#       freq                                                    2
# 3     count                                               40000
#       unique                                              40000
#       top      Frederick Ronald (Fred) Williams OBE (23 Janu...
#       freq                                                    1
# 4     count                                               40000
#       unique                                              40000
#       top      Pinson Lamar Phil McCullough (1917–2003) was ...
#       freq                                                    1
# 5     count                                               40000
#       unique                                              39998
#       top                                                   Dr.
#       freq                                                    3
# 6     count                                               40000
#       unique                                              39998
#       top      The Hero Karizma ZMR is a motorcycle manufact...
#       freq                                                    2
# 7     count                                               40000
#       unique                                              39998
#       top      Kuo Yuan Ye (Chinese: 郭元益; pinyin: Guōyuányì)...
#       freq                                                    2
# 8     count                                               40000
#       unique                                              39927
#       top             Steinkopf is a mountain of Hesse Germany.
#       freq                                                    4
# 9     count                                               40000
#       unique                                              39999
#       top      Chah Amiq-e Astan Qods (Persian: چاه عميق است...
#       freq                                                    2
# 10    count                                               40000
#       unique                                              39995
#       top      Typhlops leucomelas is a species of snake in ...
#       freq                                                    2
# 11    count                                               40000
#       unique                                              39993
#       top      The 'Buzz' series of Buddleja davidii cultiva...
#       freq                                                    4
# 12    count                                               40000
#       unique                                              39999
#       top      Before Smile Empty Soul became Smile Empty So...
#       freq                                                    2
# 13    count                                               40000
#       unique                                              40000
#       top      Tora's Pure Love (男はつらいよ 寅次郎純情詩集 Otoko wa Tsu...
#       freq                                                    1
# 14    count                                               40000
#       unique                                              39984
#       top      Tom Clancy's Net Force Explorers or Net Force...
#       freq                                                   15
#
#                                                   name
# class
# 1     count                                      40000
#       unique                                     40000
#       top                                  JMY Records
#       freq                                           1
# 2     count                                      40000
#       unique                                     40000
#       top                              RGS Springfield
#       freq                                           1
# 3     count                                      40000
#       unique                                     40000
#       top                             Blanche Forsythe
#       freq                                           1
# 4     count                                      40000
#       unique                                     40000
#       top                            Broderick Perkins
#       freq                                           1
# 5     count                                      40000
#       unique                                     40000
#       top     Philip Stanhope 5th Earl of Chesterfield
#       freq                                           1
# 6     count                                      40000
#       unique                                     40000
#       top                             Dassault Mystère
#       freq                                           1
# 7     count                                      40000
#       unique                                     40000
#       top                                  Gardencourt
#       freq                                           1
# 8     count                                      40000
#       unique                                     40000
#       top                                   Kieferbach
#       freq                                           1
# 9     count                                      40000
#       unique                                     40000
#       top                Bobrowniki Lubusz Voivodeship
#       freq                                           1
# 10    count                                      40000
#       unique                                     40000
#       top                         Setiostoma callidora
#       freq                                           1
# 11    count                                      40000
#       unique                                     40000
#       top                            Aesculus × carnea
#       freq                                           1
# 12    count                                      40000
#       unique                                     40000
#       top                                Up from Below
#       freq                                           1
# 13    count                                      40000
#       unique                                     40000
#       top                                   Maattrraan
#       freq                                           1
# 14    count                                      40000
#       unique                                     40000
#       top                        The Silver Cloud Café
#       freq                                           1

# %%
def clean_dataset(dataframe, shuffle=False, encode_ascii=False, clean_strings = False, label_prefix='__label__'):
    # Transform train file
    df = dataframe[['name','description']].apply(lambda x: x.str.replace(',',' '))
    df['class'] = label_prefix + dataframe['class'].astype(str) + ' '
    if clean_strings:
        df[['name','description']] = df[['name','description']].apply(lambda x: x.str.replace('"',''))
        df[['name','description']] = df[['name','description']].apply(lambda x: x.str.replace('\'',' \' '))
        df[['name','description']] = df[['name','description']].apply(lambda x: x.str.replace('.',' . '))
        df[['name','description']] = df[['name','description']].apply(lambda x: x.str.replace('(',' ( '))
        df[['name','description']] = df[['name','description']].apply(lambda x: x.str.replace(')',' ) '))
        df[['name','description']] = df[['name','description']].apply(lambda x: x.str.replace('!',' ! '))
        df[['name','description']] = df[['name','description']].apply(lambda x: x.str.replace('?',' ? '))
        df[['name','description']] = df[['name','description']].apply(lambda x: x.str.replace(':',' '))
        df[['name','description']] = df[['name','description']].apply(lambda x: x.str.replace(';',' '))
        df[['name','description']] = df[['name','description']].apply(lambda x: x.str.lower())
    if shuffle:
        df.sample(frac=1).reset_index(drop=True)
    if encode_ascii :
        df[['name','description']] = df[['name','description']].apply(lambda x: x.str.normalize('NFKD').str.encode('ascii','ignore').str.decode('utf-8'))
    df['name'] = ' ' + df['name'] + ' '
    df['description'] = ' ' + df['description'] + ' '
    return df

# %%
# %%time
# Transform datasets
df_train_clean = clean_dataset(df, True, False)
df_test_clean = clean_dataset(df_test, False, False)

# Write files to disk
train_file_clean = data_path + 'dbpedia.train'
df_train_clean.to_csv(train_file_clean, header=None, index=False, columns=['class','name','description'] )

test_file_clean = data_path + 'dbpedia.test'
df_test_clean.to_csv(test_file_clean, header=None, index=False, columns=['class','name','description'] )
# Out:
# CPU times: user 6.89 s, sys: 1.94 s, total: 8.84 s
# Wall time: 11.1 s

# %%
df_train_clean.head()
# Out:
#                                   name  \
# 0                    E. D. Abbott Ltd
# 1                      Schwan-Stabilo
# 2                          Q-workshop
# 3   Marvell Software Solutions Israel
# 4         Bergan Mercy Medical Center
#
#                                          description        class
# 0    Abbott of Farnham E D Abbott Limited was a B...  __label__1
# 1    Schwan-STABILO is a German maker of pens for...  __label__1
# 2    Q-workshop is a Polish company located in Po...  __label__1
# 3    Marvell Software Solutions Israel known as R...  __label__1
# 4    Bergan Mercy Medical Center is a hospital lo...  __label__1

# %%
df_train_clean.tail()
# Out:
#                               name  \
# 559995           Barking in Essex
# 559996           Science & Spirit
# 559997     The Blithedale Romance
# 559998        Razadarit Ayedawbon
# 559999   The Vinyl Cafe Notebooks
#
#                                               description         class
# 559995    Barking in Essex is a Black comedy play dire...  __label__14
# 559996    Science & Spirit is a discontinued American ...  __label__14
# 559997    The Blithedale Romance (1852) is Nathaniel H...  __label__14
# 559998    Razadarit Ayedawbon (Burmese: ရာဇာဓိရာဇ် အရေ...  __label__14
# 559999    Vinyl Cafe Notebooks: a collection of essays...  __label__14

# %%
df['description'][10]
# Out:
# ' Angstrem Group (Russian: \xd0\x9e\xd0\x90\xd0\x9e \xc2\xab\xd0\x90\xd0\xbd\xd0\xb3\xd1\x81\xd1\x82\xd1\x80\xd0\xb5\xd0\xbc\xc2\xbb named after angstrom) is a group of Russian companies one of the largest manufacturers of integrated circuits in Eastern Europe.The group includes: OAO Angstrem (the parent company design and manufacturing of electronic products and semiconductors); OAO Angstrem-M (custom design of integrated circuits staff training); OAO Angstrem-T (under-construction plant with 130-90 nm topology); OAO Angstrem-2M NGO Angstrem OAO Antek\xe2\x86\x91'

# %%
df_train_clean['description'][10]
# Out:
# '  Angstrem Group (Russian: \xd0\x9e\xd0\x90\xd0\x9e \xc2\xab\xd0\x90\xd0\xbd\xd0\xb3\xd1\x81\xd1\x82\xd1\x80\xd0\xb5\xd0\xbc\xc2\xbb named after angstrom) is a group of Russian companies one of the largest manufacturers of integrated circuits in Eastern Europe.The group includes: OAO Angstrem (the parent company design and manufacturing of electronic products and semiconductors); OAO Angstrem-M (custom design of integrated circuits staff training); OAO Angstrem-T (under-construction plant with 130-90 nm topology); OAO Angstrem-2M NGO Angstrem OAO Antek\xe2\x86\x91 '

# %%
# %%time
# Train a classifier
output_file = data_path + 'dp_model'
classifier = fasttext.supervised(train_file_clean, output_file, label_prefix='__label__')
# Out:
# CPU times: user 2min 51s, sys: 8.27 s, total: 2min 59s
# Wall time: 1min 8s

# %%
# %%time
# Evaluate classifier
result = classifier.test(test_file_clean)
print('P@1:', result.precision)
print('R@1:', result.recall)
print ('Number of examples:', result.nexamples)
# Out:
# ('P@1:', 0.9795142857142857)
# ('R@1:', 0.9795142857142857)
# ('Number of examples:', 70000)
# CPU times: user 1.87 s, sys: 448 ms, total: 2.32 s
# Wall time: 2.51 s
